# %% [markdown]
# # Pandas 50 Problems
#
# Use this notebook to solve 50 different pandas problems. Problems 1-10 are added below.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Problem 01: Clean mixed missing values
#
# Task: Fill missing numeric values with median, fill categorical values with mode, and clean placeholder values.
#
# Hint: Use `replace()`, `fillna()`, and type checks.

# %%
sales_df = pd.DataFrame({
    "order_id": [1, 2, 3, 4],
    "customer_name": ["  yashdeep ", "Aman", "aman", "Ravi "],
    "city": ["Nashik", "", "Pune", "Nashik"],
    "category": ["Electronics", "Furniture", "Electronics", None],
    "sales": [1200, np.nan, 1500, 800],
    "discount": ["10%", "NA", "15%", "5%"],
    "order_date": ["2024/01/05", "05-01-2024", "Jan 5 2024", "2024-01-06"]
})

sales_df

# %%
# Write your Problem 01 solution here

# %% [markdown]
# ## Problem 02: Standardize names and text
#
# Task: Remove extra spaces, convert names to title case, and make city values consistent.
#
# Hint: Use `str.strip()`, `str.title()`, `str.lower()`, and `replace()`.

# %%
customer_df = pd.DataFrame({
    "customer_id": [1, 2, 3, 4],
    "name": ["  yashdeep patil ", "aman singh", "  neha sharma", "ravi "],
    "city": ["nashik ", "PUNE", "mumbai", "NASHIK"]
})

customer_df

# %%
# Write your Problem 02 solution here

# %% [markdown]
# ## Problem 03: Fix inconsistent date formats
#
# Task: Convert all values in `order_date` into pandas datetime and extract year, month, and day.
#
# Hint: Use `to_datetime()` and `.dt` accessors.

# %%
orders_df = pd.DataFrame({
    "order_id": [101, 102, 103, 104, 105],
    "order_date": ["2024/01/05", "05-01-2024", "Jan 5 2024", "2024-01-06", "06 Jan, 2024"]
})

orders_df

# %%
# Write your Problem 03 solution here

# %% [markdown]
# ## Problem 04: Remove duplicates correctly
#
# Task: Remove duplicate transactions and keep only the latest unique record for each email.
#
# Hint: Use `drop_duplicates()` with `subset=` and `keep=`.

# %%
transaction_df = pd.DataFrame({
    "transaction_id": [1, 2, 3, 4, 5],
    "customer_email": ["a@gmail.com", "b@gmail.com", "a@gmail.com", "c@gmail.com", "b@gmail.com"],
    "amount": [500, 700, 500, 900, 700]
})

transaction_df

# %%
# Write your Problem 04 solution here

# %% [markdown]
# ## Problem 05: Convert wrong data types
#
# Task: Convert `price` to numeric, handle invalid entries, and identify affected rows.
#
# Hint: Use `to_numeric()` with `errors='coerce'`.

# %%
product_df = pd.DataFrame({
    "product_id": [1, 2, 3, 4],
    "product_name": ["Mouse", "Keyboard", "Monitor", "Laptop"],
    "price": ["250", "750.5", "invalid", "45000"]
})

product_df

# %%
# Write your Problem 05 solution here

# %% [markdown]
# ## Problem 06: Replace sentinel values
#
# Task: Replace placeholder strings with proper missing values and then fill them appropriately.
#
# Hint: Use `replace()` and `fillna()`.

# %%
employee_df = pd.DataFrame({
    "emp_id": [1, 2, 3, 4],
    "department": ["HR", "IT", "Sales", "Finance"],
    "manager": ["Unknown", "NA", "None", "Ramesh"]
})

employee_df

# %%
# Write your Problem 06 solution here

# %% [markdown]
# ## Problem 07: Clean column names
#
# Task: Standardize all column names to lowercase with underscores and no extra spaces.
#
# Hint: Use `df.columns = ...`, `str.strip()`, `str.lower()`, and `str.replace()`.

# %%
finance_df = pd.DataFrame({
    " Total Sales ": [10000, 15000, 12000],
    "Profit%": [20, 25, 18],
    "Region Name": ["North", "South", "West"]
})

finance_df

# %%
# Write your Problem 07 solution here

# %% [markdown]
# ## Problem 08: Split full name into parts
#
# Task: Split the full name into first name and last name columns.
#
# Hint: Use `str.split()` and column assignment.

# %%
user_df = pd.DataFrame({
    "user_id": [1, 2, 3, 4],
    "full_name": ["Yashdeep Patil", "Aman Singh", "Neha Sharma", "Ravi Kumar"]
})

user_df

# %%
# Write your Problem 08 solution here

# %% [markdown]
# ## Problem 09: Extract year from product codes
#
# Task: Extract the year part from `product_code` into a new column.
#
# Hint: Use `str.extract()` with regex.

# %%
inventory_df = pd.DataFrame({
    "item_id": [1, 2, 3, 4],
    "product_code": ["PRD-2022-001", "PRD-2023-002", "PRD-2024-003", "PRD-2024-004"]
})

inventory_df

# %%
# Write your Problem 09 solution here

# %% [markdown]
# ## Problem 10: Convert percentage text to numbers
#
# Task: Remove `%`, clean spaces, and convert the discount values into numeric form.
#
# Hint: Use `str.replace()`, `str.strip()`, and `astype()` or `to_numeric()`.

# %%
discount_df = pd.DataFrame({
    "item_id": [1, 2, 3, 4],
    "discount": ["10%", " 15 %", "25%", "100%"]
})

discount_df

# %%
# Write your Problem 10 solution here
