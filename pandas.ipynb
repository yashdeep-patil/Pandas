# %%
import numpy as np
import pandas as pd

country = ["India", "United States", "China", "Japan", "Germany", "United Kingdom", "France", "Italy", "Brazil", "Canada"]

pd.Series(country)
# Out:
# 0             India
# 1     United States
# 2             China
# 3             Japan
# 4           Germany
# 5    United Kingdom
# 6            France
# 7             Italy
# 8            Brazil
# 9            Canada
# dtype: object

# %%
runs = [100, 150, 20, 50, 00, 50, 40, 45, 50, 50]
pd.Series(runs)
# Out:
# 0    100
# 1    150
# 2     20
# 3     50
# 4      0
# 5     50
# 6     40
# 7     45
# 8     50
# 9     50
# dtype: int64

# %%
mark = [100, 150, 20, 50, 00, 50, 40, 45, 50, 50]
subject = ["Maths", "Science", "English", "History", "Geography", "Computer Science", "Physical Education", "Art", "Music", "Economics"]
pd.Series(mark, subject,name = "yashdeep")
# Out:
# Maths                 100
# Science               150
# English                20
# History                50
# Geography               0
# Computer Science       50
# Physical Education     40
# Art                    45
# Music                  50
# Economics              50
# Name: yashdeep, dtype: int64

# %%
marks = {"Maths": 100, "Science": 150, "English": 20, "History": 50, "Geography": 0, "Computer Science": 50, "Physical Education": 40, "Art": 45, "Music": 50, "Economics": 50}

marks = pd.Series(marks, name = "yashdeep")
print(marks)
marks.size
# Out:
# Maths                 100
# Science               150
# English                20
# History                50
# Geography               0
# Computer Science       50
# Physical Education     40
# Art                    45
# Music                  50
# Economics              50
# Name: yashdeep, dtype: int64
# 10

# %%
a = [1, 2, 3, 4, 5,7,45,6,77]

pd.Series(a).size
# Out:
# 9

# %%
marks.isnull()
# Out:
# Maths                 False
# Science               False
# English               False
# History               False
# Geography             False
# Computer Science      False
# Physical Education    False
# Art                   False
# Music                 False
# Economics             False
# Name: yashdeep, dtype: bool

# %%
sub = pd.read_csv('E:\Pandas\Titanic.csv\Titanic-Dataset.csv',index_col = "PassengerId")
print(sub.head())
print(sub.tail())
print(sub.sample(5))
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
sub.sort_values(by="Ticket", ascending=True)
# Out:
#              Survived  Pclass  \
# PassengerId
# 505                 1       1
# 258                 1       1
# 760                 1       1
# 263                 0       1
# 559                 1       1
# ...               ...     ...
# 236                 0       3
# 93                  0       1
# 220                 0       2
# 541                 1       1
# 746                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 505                                      Maioni, Miss. Roberta  female  16.0
# 258                                       Cherry, Miss. Gladys  female  30.0
# 760          Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0
# 263                                          Taussig, Mr. Emil    male  52.0
# 559                     Taussig, Mrs. Emil (Tillie Mandelbaum)  female  39.0
# ...                                                        ...     ...   ...
# ...

# %%
sub.sort_index(ascending=False)
# Out:
#              Survived  Pclass  \
# PassengerId
# 891                 0       3
# 890                 1       1
# 889                 0       3
# 888                 1       1
# 887                 0       2
# ...               ...     ...
# 5                   0       3
# 4                   1       1
# 3                   1       3
# 2                   1       1
# 1                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 891                                        Dooley, Mr. Patrick    male  32.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 887                                      Montvila, Rev. Juozas    male  27.0
# ...                                                        ...     ...   ...
# ...

# %%
sub["Age"].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
sub.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
sub["Fare"].var()
# Out:
# np.float64(2469.436845743116)

# %%
sub
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
sub[(sub["Age"] >= 18) & ~(sub["Sex"] == "female" )]
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 13                  0       3  Saundercock, Mr. William Henry  male  20.0
# 14                  0       3     Andersson, Mr. Anders Johan  male  39.0
# ...               ...     ...                             ...   ...   ...
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 890                 1       1           Behr, Mr. Karl Howell  male  26.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
sub.plot(kind="line")
# Out:
# <Axes: xlabel='PassengerId'>

# %%
sub.drop(columns=["Sex","Age","Ticket"])
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  SibSp  Parch  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      1      0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# 3                                       Heikkinen, Miss. Laina      0      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# 5                                     Allen, Mr. William Henry      0      0
# ...                                                        ...    ...    ...
# ...

# %%
sub.fillna(1234)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
sub.dropna(axis=1)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1
# 3                                       Heikkinen, Miss. Laina  female      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1
# 5                                     Allen, Mr. William Henry    male      0
# ...                                                        ...     ...    ...
# ...

# %%
sub.duplicated
sub.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
sub["Name"].isin(["yashdeep","Montvila, Rev. Juozas"]).sum()
# Out:
# np.int64(1)

# %%
sub.apply(lambda x: x * 2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       6
# 2                   2       2
# 3                   2       6
# 4                   2       2
# 5                   0       6
# ...               ...     ...
# 887                 0       4
# 888                 2       2
# 889                 0       6
# 890                 2       2
# 891                 0       6
#
#                                                           Name           Sex  \
# PassengerId
# 1               Braund, Mr. Owen HarrisBraund, Mr. Owen Harris      malemale
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  femalefemale
# 3                 Heikkinen, Miss. LainaHeikkinen, Miss. Laina  femalefemale
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)Fu...  femalefemale
# 5             Allen, Mr. William HenryAllen, Mr. William Henry      malemale
# ...                                                        ...           ...
# ...

# %%
subs = sub.copy() 
subs
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
sub.rename(columns={"Age":"actor_age"})
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
sub[["Age"]]
sub[["Age","Fare"]]
# Out:
#               Age     Fare
# PassengerId
# 1            22.0   7.2500
# 2            38.0  71.2833
# 3            26.0   7.9250
# 4            35.0  53.1000
# 5            35.0   8.0500
# ...           ...      ...
# 887          27.0  13.0000
# 888          19.0  30.0000
# 889           NaN  23.4500
# 890          26.0  30.0000
# 891          32.0   7.7500
#
# [891 rows x 2 columns]

# %%
sub.iloc[:,0:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
sub.iloc[0]
# Out:
# Survived                          0
# Pclass                            3
# Name        Braund, Mr. Owen Harris
# Sex                            male
# Age                            22.0
# SibSp                             1
# Parch                             0
# Ticket                    A/5 21171
# Fare                           7.25
# Cabin                           NaN
# Embarked                          S
# Name: 1, dtype: object

# %%
sub.iloc[:,0]
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
sub.loc[:5,["Age","Fare"]]
# Out:
#               Age     Fare
# PassengerId
# 1            22.0   7.2500
# 2            38.0  71.2833
# 3            26.0   7.9250
# 4            35.0  53.1000
# 5            35.0   8.0500

# %%
sub["Name"].str.upper()
# Out:
# PassengerId
# 1                                BRAUND, MR. OWEN HARRIS
# 2      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 3                                 HEIKKINEN, MISS. LAINA
# 4           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 5                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 887                                MONTVILA, REV. JUOZAS
# 888                         GRAHAM, MISS. MARGARET EDITH
# 889             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 890                                BEHR, MR. KARL HOWELL
# 891                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
sub["Name"].str.contains("Mr")
# Out:
# PassengerId
# 1       True
# 2       True
# 3      False
# 4       True
# 5       True
#        ...
# 887    False
# 888    False
# 889    False
# 890     True
# 891     True
# Name: Name, Length: 891, dtype: bool

# %%
sub
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
sub["Adult"]= sub["Age"] >= 18
sub
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
sub["status"] = sub["Age"].apply(lambda x: "Adult" if x >= 18 else "Child")
sub
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
sub.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
sub.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Adult', 'status'],
#       dtype='object')

# %%
sub.groupby("Pclass")["Age"].count()
# Out:
# Pclass
# 1    186
# 2    173
# 3    355
# Name: Age, dtype: int64

# %%
sub.groupby("Pclass")["Ticket"].sum()
# Out:
# Pclass
# 1    PC 175991138031746311378311378819950PC 17601PC...
# 2    237736248706244373239865248698C.A. 2457911668S...
# 3    A/5 21171STON/O2. 3101282373450330877349909347...
# Name: Ticket, dtype: object

# %%
sub.groupby("Pclass")["Fare"].max()
# Out:
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
sub.groupby("Sex")["Age"].min()
# Out:
# Sex
# female    0.75
# male      0.42
# Name: Age, dtype: float64

# %%
sub.groupby("Sex")["Age"].count()
# Out:
# Sex
# female    261
# male      453
# Name: Age, dtype: int64

# %%
sub.groupby("Sex")["Fare"].mean()
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
sub.groupby("Pclass")["Fare"].agg(["min","max","mean"])
# Out:
#         min       max       mean
# Pclass
# 1       0.0  512.3292  84.154687
# 2       0.0   73.5000  20.662183
# 3       0.0   69.5500  13.675550

# %%
sub.groupby("Pclass").agg({"Age":["mean"],"Fare":["max","sum"]})
# Out:
#               Age      Fare
#              mean       max         sum
# Pclass
# 1       38.233441  512.3292  18177.4125
# 2       29.877630   73.5000   3801.8417
# 3       25.140620   69.5500   6714.6951

# %%
sub.groupby("Sex").agg({"Age":["mean","min","max"],"Fare":"size"})
# Out:
#               Age             Fare
#              mean   min   max size
# Sex
# female  27.915709  0.75  63.0  314
# male    30.726645  0.42  80.0  577

# %%
sub.groupby("Pclass").agg({"Age":["mean","median","std"],"Fare":"size"})
# Out:
#               Age                   Fare
#              mean median        std size
# Pclass
# 1       38.233441   37.0  14.802856  216
# 2       29.877630   29.0  14.001077  184
# 3       25.140620   24.0  12.495398  491

# %%
sub.groupby(["Sex","Pclass"]).agg({"Fare":["mean"],"Age":["mean"]})
# Out:
#                      Fare        Age
#                      mean       mean
# Sex    Pclass
# female 1       106.125798  34.611765
#        2        21.970121  28.722973
#        3        16.118810  21.750000
# male   1        67.226127  41.281386
#        2        19.741782  30.740707
#        3        12.661633  26.507589

# %%
sub.groupby(["Sex","Pclass"]).agg({"Age":["mean","min","max"],"Fare":["mean","size","count"]})
# Out:
#                      Age                    Fare
#                     mean   min   max        mean size count
# Sex    Pclass
# female 1       34.611765  2.00  63.0  106.125798   94    94
#        2       28.722973  2.00  57.0   21.970121   76    76
#        3       21.750000  0.75  63.0   16.118810  144   144
# male   1       41.281386  0.92  80.0   67.226127  122   122
#        2       30.740707  0.67  70.0   19.741782  108   108
#        3       26.507589  0.42  74.0   12.661633  347   347

# %%
sub["Age mean sex"]= sub.groupby("Sex")["Age"].transform("mean")
sub
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
sub["Fare mean class"] = sub.groupby("Pclass")["Fare"].transform("mean")
sub
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
g = sub.groupby("Pclass")
g.nth(1)
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 16                  1       2              Hewlett, Mrs. (Mary D Kingcome)
#
#                 Sex   Age  SibSp  Parch            Ticket    Fare Cabin  \
# PassengerId
# 3            female  26.0      0      0  STON/O2. 3101282   7.925   NaN
# 4            female  35.0      1      0            113803  53.100  C123
# 16           female  55.0      0      0            248706  16.000   NaN
#
#             Embarked  Adult status  Age mean sex  Fare mean class
# PassengerId
# 3                  S   True  Adult     27.915709        13.675550
# 4                  S   True  Adult     27.915709        84.154687
# 16                 S   True  Adult     27.915709        20.662183

# %%
g = sub.groupby("Pclass")
g.last(),g.first()
# Out:
# (        Survived                   Name   Sex   Age  SibSp  Parch  Ticket  \
#  Pclass
#  1              1  Behr, Mr. Karl Howell  male  26.0      0      0  111369
#  2              0  Montvila, Rev. Juozas  male  27.0      0      0  211536
#  3              0    Dooley, Mr. Patrick  male  32.0      0      0  370376
#
#           Fare Cabin Embarked  Adult status  Age mean sex  Fare mean class
#  Pclass
#  1       30.00  C148        C   True  Adult     30.726645        84.154687
#  2       13.00   E77        S   True  Adult     30.726645        20.662183
#  3        7.75  E121        Q   True  Adult     30.726645        13.675550  ,
#          Survived                                               Name     Sex  \
#  Pclass
#  1              1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
#  2              1                Nasser, Mrs. Nicholas (Adele Achem)  female
#  3              0                            Braund, Mr. Owen Harris    male
#
# ...

# %%
g = sub.groupby("Pclass")
g.nth([0,-1])
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 10                  1       2
# 887                 0       2
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 887                                      Montvila, Rev. Juozas    male  27.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked  Adult status  \
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S   True  Adult
# ...

# %%
g = sub.groupby("Pclass")
g.sample(3)
# Out:
#              Survived  Pclass                                   Name     Sex  \
# PassengerId
# 454                 1       1               Goldenberg, Mr. Samuel L    male
# 725                 1       1          Chambers, Mr. Norman Campbell    male
# 376                 1       1  Meyer, Mrs. Edgar Joseph (Leila Saks)  female
# 418                 1       2          Silven, Miss. Lyyli Karoliina  female
# 809                 0       2                      Meyer, Mr. August    male
# 530                 0       2            Hocking, Mr. Richard George    male
# 177                 0       3          Lefebre, Master. Henry Forbes    male
# 502                 0       3                    Canavan, Miss. Mary  female
# 331                 1       3                     McCoy, Miss. Agnes  female
#
#               Age  SibSp  Parch    Ticket     Fare Cabin Embarked  Adult  \
# PassengerId
# 454          49.0      1      0     17453  89.1042   C92        C   True
# ...

# %%
g = sub.groupby("Pclass")
g.nunique()
# Out:
#         Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  Embarked  \
# Pclass
# 1              2   216    2   57      4      4     147    94    133         3
# 2              2   184    2   57      4      4     140    42      7         3
# 3              2   491    2   68      7      7     394   119      7         3
#
#         Adult  status  Age mean sex  Fare mean class
# Pclass
# 1           2       2             2                1
# 2           2       2             2                1
# 3           2       2             2                1

# %%
g = sub.groupby("Sex").groups["female"]
g
# Out:
# Index([  2,   3,   4,   9,  10,  11,  12,  15,  16,  19,
#        ...
#        867, 872, 875, 876, 880, 881, 883, 886, 888, 889],
#       dtype='int64', name='PassengerId', length=314)

# %%
g = sub.groupby("Pclass").get_group(2)
g
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 10                  1       2           Nasser, Mrs. Nicholas (Adele Achem)
# 16                  1       2              Hewlett, Mrs. (Mary D Kingcome)
# 18                  1       2                  Williams, Mr. Charles Eugene
# 21                  0       2                          Fynney, Mr. Joseph J
# 22                  1       2                         Beesley, Mr. Lawrence
# ...               ...     ...                                           ...
# 867                 1       2                  Duran y More, Miss. Asuncion
# 875                 1       2         Abelson, Mrs. Samuel (Hannah Wizosky)
# 881                 1       2  Shelley, Mrs. William (Imanita Parrish Hall)
# 884                 0       2                 Banfield, Mr. Frederick James
# 887                 0       2                         Montvila, Rev. Juozas
#
# ...

# %%
g = sub.groupby("Pclass")["Fare"].describe()
g
# Out:
#         count       mean        std  min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %%
g = sub.groupby("Sex")

len(g)

list(g.groups.keys())

g.get_group("female")

g.first()

g.last()
# Out:
#         Survived  Pclass                                      Name   Age  \
# Sex
# female         0       3  Johnston, Miss. Catherine Helen "Carrie"  19.0
# male           0       3                       Dooley, Mr. Patrick  32.0
#
#         SibSp  Parch      Ticket   Fare Cabin Embarked  Adult status  \
# Sex
# female      1      2  W./C. 6607  23.45   B42        S  False  Child
# male        0      0      370376   7.75  C148        Q   True  Adult
#
#         Age mean sex  Fare mean class
# Sex
# female     27.915709         13.67555
# male       30.726645         13.67555

# %%
sub.groupby("Pclass").apply(lambda x:(string, RIGHT(string, 3)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 sub.groupby("Pclass").apply(lambda x:(string, RIGHT(string, 3)))
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1826, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1824 with option_context("mode.chained_assignment", None):
#    1825     try:
# -> 1826         result = self._python_apply_general(f, self._selected_obj)
#    1827         if (
#    1828             not isinstance(self.obj, Series)
#    1829             and self._selection is None
#    1830             and self._selected_obj.shape != self._obj_with_exclusions.shape
#    1831         ):
#    1832             warnings.warn(
#    1833                 message=_apply_groupings_depr.format(
#    1834                     type(self).__name__, "apply"
#    (...)
# ...

# %%
sub.groupby("Pclass").apply(lambda x: x.tail(3))

# %%
s = sub.groupby("Sex")["Age"].mean()
type(s)

# %%
k = sub.groupby("Sex")["Age"].mean()
s.reset_index()

# %%
j = sub.groupby(["Sex","Pclass"])["Age"].mean()
j.unstack(level=0)

# %%
kub = pd.read_csv("E:\Pandas\movies.csv")
kub
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
pd.merge(kub,sub, left_index=True,right_index=True,how='left')
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
sub
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
kub
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 kub
#
# NameError: name 'kub' is not defined

# %%
df1 = pd.DataFrame({
    'id':[1,2,3,4],
    'name':['A','B','C','D']
})

df2 = pd.DataFrame({
    'id':[2,3,5],
    'salary':[100,200,300]
})

# %%
pd.merge(df1,df2,on="id",how="inner")
# Out:
#    id name  salary
# 0   2    B     100
# 1   3    C     200

# %%
pd.merge(df1,df2, on="id",how="left")
# Out:
#    id name  salary
# 0   1    A     NaN
# 1   2    B   100.0
# 2   3    C   200.0
# 3   4    D     NaN

# %%
pd.merge(df1,df2,on="id",how="outer")
# Out:
#    id name  salary
# 0   1    A     NaN
# 1   2    B   100.0
# 2   3    C   200.0
# 3   4    D     NaN
# 4   5  NaN   300.0

# %%
pd.concat([sub,kub])
# Out:
#       Survived  Pclass                                               Name  \
# 1          0.0     3.0                            Braund, Mr. Owen Harris
# 2          1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3          1.0     3.0                             Heikkinen, Miss. Laina
# 4          1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5          0.0     3.0                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1624       NaN     NaN                                                NaN
# 1625       NaN     NaN                                                NaN
# 1626       NaN     NaN                                                NaN
# 1627       NaN     NaN                                                NaN
# 1628       NaN     NaN                                                NaN
#
#          Sex   Age  SibSp  Parch            Ticket     Fare Cabin  ...  \
# ...

# %%
sub.join(kub)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df1 = pd.DataFrame({
    'name':['A','B','C']
}, index=[1,2,3])

df2 = pd.DataFrame({
    'salary':[100,200,400]
}, index=[1,2,4])

# %%
df1.join(df2,how="outer")
# Out:
#   name  salary
# 1    A   100.0
# 2    B   200.0
# 3    C     NaN
# 4  NaN   400.0

# %%
df1 = pd.DataFrame({
    'emp_id':[1,2,3],
    'name':['A','B','C']
})

df2 = pd.DataFrame({
    'id':[1,2,4],
    'salary':[100,200,400]
})

pd.merge(df1,df2,left_on='emp_id',right_on='id',how='inner')
# Out:
#    emp_id name  id  salary
# 0       1    A   1     100
# 1       2    B   2     200

# %%
pd.merge(df1,df2,left_on='emp_id',right_on='id')
# Out:
#    emp_id name  id  salary
# 0       1    A   1     100
# 1       2    B   2     200

# %%
df1 = pd.DataFrame({
    'id':[1,2,3,4],
    'name':['A','B','C','D']
})
df2 = pd.DataFrame({
    'id':[2,3,5],
    'salary':[100,200,300]
})

hhh = pd.merge(df1,
         df2,
         on='id',
         how='outer',
         indicator=True)
hhh
# Out:
#    id name  salary      _merge
# 0   1    A     NaN   left_only
# 1   2    B   100.0        both
# 2   3    C   200.0        both
# 3   4    D     NaN   left_only
# 4   5  NaN   300.0  right_only

# %%
hhh.fillna({"name": 'E',"salary": '50'})
# Out:
#    id name salary      _merge
# 0   1    A     50   left_only
# 1   2    B  100.0        both
# 2   3    C  200.0        both
# 3   4    D     50   left_only
# 4   5    E  300.0  right_only

# %%
result = pd.merge(df1,df2,on='id',how='outer',indicator=True)
result[result['_merge']=='right_only']
# Out:
#    id name  salary      _merge
# 4   5  NaN   300.0  right_only

# %%
df1 = pd.DataFrame(
    {'Name':['A','B'] }
)

df2 = pd.DataFrame(
    {'Salary':[100,200] }
)

pd.concat([df1,df2],axis=1)
# Out:
#   Name  Salary
# 0    A     100
# 1    B     200

# %%
s = pd.pivot_table(sub,index='Sex',columns='Pclass',values='Fare',aggfunc='mean')
s
# Out:
# Pclass           1          2          3
# Sex
# female  106.125798  21.970121  16.118810
# male     67.226127  19.741782  12.661633

# %%
print(s.columns)
# Out:
# Index([1, 2, 3], dtype='int64', name='Pclass')

# %%
print(s)

# %%
h = pd.pivot_table(sub, index='Sex', columns='Pclass', values='Age', aggfunc=['mean','min','max'],margins=True)
h
# Out:
#              mean                                    min                    \
# Pclass          1          2          3        All     1     2     3   All
# Sex
# female  34.611765  28.722973  21.750000  27.915709  2.00  2.00  0.75  0.75
# male    41.281386  30.740707  26.507589  30.726645  0.92  0.67  0.42  0.42
# All     38.233441  29.877630  25.140620  29.699118  0.92  0.67  0.42  0.42
#
#          max
# Pclass     1     2     3   All
# Sex
# female  63.0  57.0  63.0  63.0
# male    80.0  70.0  74.0  80.0
# All     80.0  70.0  74.0  80.0

# %%
h = pd.pivot_table(sub, index='Sex', columns='Embarked', values='Age', aggfunc=['mean','min','max'],fill_value=0)
h
# Out:
#                mean                         min               max
# Embarked          C          Q          S     C     Q     S     C     Q     S
# Sex
# female    28.344262  24.291667  27.771505  0.75  15.0  1.00  60.0  39.0  63.0
# male      32.998841  30.937500  30.291440  0.42   2.0  0.67  71.0  70.5  80.0

# %%
df = pd.DataFrame({
    'Gender':['Male','Female','Male','Female',
              'Male','Female','Male','Female'],
    
    'Pclass':[1,1,2,2,3,3,1,2]
})
df
# Out:
#    Gender  Pclass
# 0    Male       1
# 1  Female       1
# 2    Male       2
# 3  Female       2
# 4    Male       3
# 5  Female       3
# 6    Male       1
# 7  Female       2

# %%
pd.crosstab(df['Gender'],df['Pclass'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 pd.crosstab(df['Gender'],df['Pclass'])
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame({
    'Name':['A','B'],
    'Math':[80,90],
    'Science':[70,85]
})

df.melt(id_vars='Name')
# Out:
#   Name variable  value
# 0    A     Math     80
# 1    B     Math     90
# 2    A  Science     70
# 3    B  Science     85

# %%
df = pd.DataFrame({
    'Name':['  YASH  ',
            ' RAJ',
            'PATIL  ']
})

df['Name'].str.strip().str.lower()
# Out:
# 0     yash
# 1      raj
# 2    patil
# Name: Name, dtype: object

# %%
df = pd.DataFrame({
    'Name':[
        'Mr. Yash',
        'Mr. Raj',
        'Mr. Patil'
    ]
})

df['Name'].str.replace('Mr.','')
# Out:
# 0       Yash
# 1        Raj
# 2      Patil
# Name: Name, dtype: object
